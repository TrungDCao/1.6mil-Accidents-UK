# %%
import geopandas as gpd
import pandas as pd

# %%
gdf = gpd.read_file(r"C:\Users\DETCAO03\V-Case study\02_Dataset\data\oproad_gb.gpkg")

# %%
gdff = pd.DataFrame(gdf)
gdf.plot()
# Out:
# <AxesSubplot:>

# %%
gdff.head()
# Out:
#                                        id  \
# 0  idBFCE4F5E-C578-46D6-996C-897C1BAE197A
# 1  id7F167BE3-8EAC-4B20-8CC8-0C0908A64402
# 2  id8C59F02C-51CB-4980-B5EC-36D6E18C3A5A
# 3  idC68A3C74-1538-4BB5-B1E6-7BC82D7C0428
# 4  idD7E39603-32D8-47B7-8E8B-0C239F706DE6
#
#                                   endNode  \
# 0  id38E2140E-2F55-40F5-A739-65EBD0AA74F3
# 1  id8F16FE73-3DB4-4A7E-AD23-622DF194D10B
# 2  id38E2140E-2F55-40F5-A739-65EBD0AA74F3
# 3  id6F1E9DE0-B5C1-45F8-8E78-016E3A6325BB
# 4  idCD4329C2-3992-4C38-8AC6-99B229B7EE66
#
#                                 startNode roadNumberTOID roadNameTOID  \
# 0  id07454B04-8348-4DDA-B766-41274E3190DD           None         None
# 1  id399302F8-5DC0-496D-AB11-8CF63CBEB339           None         None
# 2  id1CAE06B1-59CE-4B72-B364-E1B24AB98EFE           None         None
# 3  id38E2140E-2F55-40F5-A739-65EBD0AA74F3           None         None
# 4  id07454B04-8348-4DDA-B766-41274E3190DD           None         None
#
# ...

# %%
#for i in gdff:
 #   print (gdff[i].name+":")
  #  print (gdff[i].sort_values().unique())
   # print ("\n")
# Out:
# id:
# ['id00000819-DFE7-4787-8AF8-A799B6EED2B5'
#  'id00000C71-4FB9-47B2-BC94-7727F60F50E3'
#  'id00000E3A-E125-48E6-B056-7EFB6AD947B6' ...
#  'idFFFFF18C-F4EF-4A1D-A694-82DED0C841EF'
#  'idFFFFF4D1-DF9A-4357-9B2E-9D45BCA7D252'
#  'idFFFFFF27-953A-4809-892A-EB55B39236E4']
#
#
# endNode:
# ['id00000461-1C8C-4183-9B23-DADCF83FE99F'
#  'id00000532-3F19-487A-ABBC-FC4F1CFD23C6'
#  'id00001014-14E1-42AB-AB79-C5262E2BAB6B' ...
#  'idFFFFF232-88FC-477D-B704-81E541A06D74'
#  'idFFFFFA25-0F3F-4F95-BC2C-B5D6430B7AD5'
#  'idFFFFFC66-F4E1-47EC-9BB9-68F5119D7D6B']
#
#
# startNode:
# ['id00000461-1C8C-4183-9B23-DADCF83FE99F'
#  'id00000532-3F19-487A-ABBC-FC4F1CFD23C6'
#  'id00001014-14E1-42AB-AB79-C5262E2BAB6B' ...
#  'idFFFFEFC6-7868-40B3-86BF-206D3922A290'
#  'idFFFFF232-88FC-477D-B704-81E541A06D74'
#  'idFFFFFC66-F4E1-47EC-9BB9-68F5119D7D6B']
#
#
# roadNumberTOID:
# ['osgb4000000003210681' 'osgb4000000003210682' 'osgb4000000003210683' ...
#  'osgb5000005274451387' 'osgb5000005274599634' None]
#
# ...
